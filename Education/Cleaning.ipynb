# %%
import pandas as pd
df=pd.read_csv(r"c:\Users\HP\Desktop\PERSONAL PROJECTS\Cricket.csv")
pd.set_option('display.max_rows',None)
df.head(5)
# Out:
#               Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0   DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1     AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2    RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 3    GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 4  H Sutcliffe (ENG)  1924-1935   54    84   9  4555   194  60.73  6558+
#
#       SR  100  50  0   4s  6s
# 0  58.60   29  13  7  626   6
# 1  55.68    5   4  2  186   5
# 2  54.48    7  11  1  246  11
# 3  56.00   10   5  2  104   1
# 4  34.59   16  23  2  202   6

# %%
#Renaming Colums
df=df.rename(columns={'Mat':'Matches_Played','NO':'Not_Outs','HS':'Highest_inns_Score','BF':'Balls_Face','SR':'Batting_Strike_Rate'})
df.head()
df.sample()
# Out:
#               Player       Span  Matches_Played  Inns  Not_Outs   Runs  \
# 14    L Hutton (ENG)  1937-1955              79   138        15   6971
# 31     J Ryder (AUS)  1920-1929              20    32         5   1394
# 30  RT Ponting (AUS)  1995-2012             168   287        29  13378
# 10    GS Sobers (WI)  1954-1974              93   160        21   8032
# 20   VG Kambli (IND)  1993-1995              17    21         1   1084
#
#    Highest_inns_Score    Ave Balls_Face  Batting_Strike_Rate  100  50   0  \
# 14                364  56.67      2844+                39.34   19  33   5
# 31               201*  51.62      2035+                44.86    3   9   1
# 30                257  51.85      22782                58.72   41  62  17
# 10               365*  57.78      4063+                53.58   26  30  12
# 20                227  54.20       1823                59.46    4   3   3
#
#       4s  6s
# 14   358   7
# 31   102   3
# 30  1509  73
# 10   593  32
# 20   124   6

# %%
#Checking for Null Values
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches_Played         False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_inns_Score     False
# Ave                    False
# Balls_Face             False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool
